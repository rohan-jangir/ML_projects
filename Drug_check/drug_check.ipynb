# %% [markdown]
# # 🌟 About This Code: Drug Classification using Decision Trees 🌟
#
# ## This Python code aims to classify drugs based on patient attributes using a Decision Tree Classifier. Below is an overview of the code functionality:
#
# ### 📊 Data Loading and Visualization:
#
# * The code starts by importing necessary libraries such as Pandas, NumPy, Matplotlib, Seaborn, and scikit-learn.
# * It loads a drug dataset named 'drug200.csv' into a Pandas DataFrame.
# * For each feature column in the dataset, it creates scatter plots to visualize the relationship between each feature and the target variable 'Drug'.
# * It also generates a pie chart to visualize the distribution of drugs in the dataset.
#
# ### 🛠️ Data Preprocessing:
#
# * The code encodes categorical features using LabelEncoder from scikit-learn, specifically 'Sex', 'BP', and 'Cholesterol'.
# * This step prepares the data for training the Decision Tree Classifier.
#
# ### 🎓 Model Training and Prediction:
#
# * It splits the dataset into training and testing sets using train_test_split function.
# * The Decision Tree Classifier model is trained using the training data.
# * The user is prompted to input values for patient attributes: 'Age', 'Sex', 'BP', 'Cholesterol', and 'Na_to_K'.
# * Based on the input values, the model predicts the preferred drug for the patient.
# * The predicted drug is then displayed to the user.
#
# ### 📈 Model Evaluation:
#
# * The code calculates the accuracy score of the trained model on the training data using the score method.
# * This code provides a simple interface for predicting the preferred drug for a patient based on their attributes using a Decision Tree Classifier. It * utilizes a drug dataset with columns including 'Age', 'Sex', 'BP', 'Cholesterol', and 'Na_to_K' to demonstrate the classification process in a healthcare context.

# %% [markdown]
# # Import the neccecary liabraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the Data of diffrent type of Drug based on patient disease

# %%
df = pd.read_csv('drug200.csv')

# %% [markdown]
# # Explore the data

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %% [markdown]
# # Explore the behavior of the data by using diffrent type og plot

# %% [markdown]
# ### 1. Histograms
# * A histogram is a graphical representation of the distribution of a dataset. It is used to visualize the frequency or count of data points that fall within specified ranges (bins) of a continuous variable.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 2. pie chart
# * A pie chart is a circular statistical graphic that is divided into slices to illustrate numerical proportions.

# %%
plt.figure(figsize=(8, 8))
df['Drug'].value_counts().plot(kind='pie',autopct='%2f')
plt.title('Distribution of Drugs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 3. Bar Plots
# * A bar graph (or bar chart) is a graphical representation of data where individual bars represent the quantity or frequency of different categories

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='Sex')
plt.title('Count of Patients by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='BP')
plt.title('Count of Patients by Blood Pressure')
plt.xlabel('Blood Pressure')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='Cholesterol')
plt.title('Count of Patients by Cholesterol Level')
plt.xlabel('Cholesterol Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 4. Box Plots
# * A box plot, also known as a whisker plot, is a standardized way of displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), median, third quartile (Q3), and maximum.

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(data=df, x='Sex', y='Age')
plt.title('Distribution of Age by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### 5. Heatmap
# * Heatmaps are particularly useful for displaying the magnitude of values across two dimensions, such as the correlation between variables in a dataset.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## LabelEncoder.
# * The LabelEncoder in scikit-learn is a utility class used for encoding categorical features into numerical values

# %%
from sklearn.preprocessing import LabelEncoder
for i in df.columns:
    if i=='Na_to_K':
        continue
    elif i=='Age':
        continue
    else:  
        a = LabelEncoder()
        new_col = a.fit_transform(df[i])
        df[i] = new_col

# %% [markdown]
# ### 6. pairplot
# * A pair plot, also known as a scatterplot matrix, is a useful visualization for understanding the pairwise relationships between multiple variables in a dataset. It creates a grid of scatterplots, where each plot shows the relationship between a pair of variables.

# %%
sns.pairplot(df)

# %% [markdown]
# # Train the model with loaded dataset drug200

# %%
# train the model using decision tree classifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
model = DecisionTreeClassifier()

# %%
# split data into dependent and independent data

x = df[['Age','BP','Cholesterol','Sex','Na_to_K']]
y = df['Drug']
Xtrain,Xtest,ytrain,ytest = train_test_split(x,y)

# %%
# fitt the train and test value in decision tree classifier model

model.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
# predict the test values

model.predict(Xtest)
# Out:
# array([4, 3, 4, 4, 3, 2, 1, 4, 4, 3, 4, 0, 4, 4, 3, 3, 4, 0, 3, 0, 3, 4,
#        1, 3, 0, 4, 4, 4, 4, 3, 4, 3, 4, 4, 0, 1, 0, 4, 0, 3, 3, 3, 2, 3,
#        4, 0, 1, 3, 3, 3])

# %% [markdown]
# # Convert Drug numeric value into string value for getting output in drug name

# %%
col1 = int(input('Enter First Value'))
col2 = int(input('Enter second Value'))
col3 = int(input('Enter third Value'))
col4 = int(input('Enter fourth Value'))
col5 = int(input('Enter fifth Value'))
d = pd.DataFrame([{'Age':col1,'BP':col2,'Cholesterol':col3,'Sex':col4,'Na_to_K':col5}])

for predict in model.predict(d):
    if predict==4:
        predict='DrugY'
    elif predict == 3:
        predict='DrugX'
    elif predict == 2:
        predict='DrugC'
    elif predict == 1:
        predict='DrugB'
    else:
        predict='DrugA'
    print('Your Prefered Drug is:  ',predict)
# Out:
# Enter First Value 8
# Enter second Value 0
# Enter third Value 0
# Enter fourth Value 0
# Enter fifth Value 167
# Your Prefered Drug is:   DrugY

# %% [markdown]
# # Check our model score which is good or bad

# %%
# check the model accuracy.

model.score(Xtrain,ytrain)
# Out:
# 1.0

# %% [markdown]
# ### 🔍 Conclusion:
# * This code successfully demonstrates how a Decision Tree Classifier can be used to predict the preferred drug for a patient based on their attributes.
# * Through data visualization, preprocessing, model training, and evaluation, we've gained insights into the dataset and developed an accurate prediction model.
#
# ### 📌 Recommendations:
# * - Further exploration could involve experimenting with different machine learning algorithms to compare their performance.
# * - Collecting more diverse and comprehensive data could enhance the model's predictive capabilities.
#
# ### ⚠️ Limitations:
# * - The accuracy of the model may vary depending on the quality and quantity of the data.
# * - This analysis assumes that the Decision Tree Classifier is the most suitable model for this task; other models should also be considered.
#
# ### 🌟 Thank you for exploring this code with us! We hope it inspires further exploration and insights into drug classification.
